# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key

# %%
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 755

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=bb5e0a68a2265eb91063517a875429ea'

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                            "Country": city_country,
                            "Lat": city_lat,
                            "Lng": city_lng,
                            "Max Temp": city_max_temp,
                            "Humidity": city_humidity,
                            "Cloudiness": city_clouds,
                            "Wind Speed": city_wind,
                            "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | novo aripuana
# Processing Record 3 of Set 1 | aksarka
# Processing Record 4 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 1 | pilar do sul
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | cayenne
# Processing Record 8 of Set 1 | bethanien
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | pahrump
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | georgetown
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | dubbo
# Processing Record 15 of Set 1 | new norfolk
# Processing Record 16 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 17 of Set 1 | hambantota
# Processing Record 18 of Set 1 | nome
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | bambous virieux
# Processing Record 21 of Set 1 | merauke
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | husavik
# Processing Record 24 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 1 | cape town
# Processing Record 26 of Set 1 | berbera
# Processing Record 27 of Set 1 | leningradskiy
# Processing Record 28 of Set 1 | dikson
# Processing Record 29 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 30 of Set 1 | andros
# Processing Record 31 of Set 1 | les escoumins
# Processing Record 32 of Set 1 | busselton
# Processing Record 33 of Set 1 | grindavik
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | kedrovyy
# Processing Record 36 of Set 1 | muros
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 41 of Set 1 | pirgos
# Processing Record 42 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 1 | lorengau
# Processing Record 44 of Set 1 | tiarei
# Processing Record 45 of Set 1 | dawei
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | khatanga
# Processing Record 49 of Set 1 | torbay
# Processing Record 50 of Set 1 | charters towers
# Processing Record 1 of Set 2 | xinyu
# Processing Record 2 of Set 2 | lompoc
# Processing Record 3 of Set 2 | karoi
# Processing Record 4 of Set 2 | tabou
# Processing Record 5 of Set 2 | pisco
# Processing Record 6 of Set 2 | gannavaram
# Processing Record 7 of Set 2 | monte aprazivel
# Processing Record 8 of Set 2 | dutse
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | puerto ayora
# Processing Record 11 of Set 2 | sioux lookout
# Processing Record 12 of Set 2 | nuevo laredo
# Processing Record 13 of Set 2 | san carlos de bariloche
# Processing Record 14 of Set 2 | oyama
# Processing Record 15 of Set 2 | cozumel
# Processing Record 16 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 2 | tiksi
# Processing Record 18 of Set 2 | portland
# Processing Record 19 of Set 2 | thompson
# Processing Record 20 of Set 2 | castro
# Processing Record 21 of Set 2 | taguatinga
# Processing Record 22 of Set 2 | vardo
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | camacha
# Processing Record 25 of Set 2 | skjervoy
# Processing Record 26 of Set 2 | ribeira grande
# Processing Record 27 of Set 2 | hamilton
# Processing Record 28 of Set 2 | hithadhoo
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | luderitz
# Processing Record 31 of Set 2 | kismayo
# Processing Record 32 of Set 2 | yulara
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | constitucion
# Processing Record 35 of Set 2 | longyearbyen
# Processing Record 36 of Set 2 | bengkulu
# Processing Record 37 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 38 of Set 2 | awbari
# Processing Record 39 of Set 2 | tura
# Processing Record 40 of Set 2 | hofn
# Processing Record 41 of Set 2 | baiyin
# Processing Record 42 of Set 2 | faanui
# Processing Record 43 of Set 2 | esperance
# Processing Record 44 of Set 2 | saint-philippe
# Processing Record 45 of Set 2 | matsuura
# Processing Record 46 of Set 2 | east london
# Processing Record 47 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 2 | camapua
# Processing Record 49 of Set 2 | lavrentiya
# Processing Record 50 of Set 2 | lebu
# Processing Record 1 of Set 3 | saskylakh
# Processing Record 2 of Set 3 | kruisfontein
# Processing Record 3 of Set 3 | bethel
# Processing Record 4 of Set 3 | altamont
# Processing Record 5 of Set 3 | mikhaylovka
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | carnarvon
# Processing Record 9 of Set 3 | strai
# Processing Record 10 of Set 3 | qaanaaq
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 3 | yueyang
# Processing Record 14 of Set 3 | lagoa
# Processing Record 15 of Set 3 | provideniya
# Processing Record 16 of Set 3 | kargasok
# Processing Record 17 of Set 3 | kandi
# Processing Record 18 of Set 3 | caravelas
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | kavaratti
# Processing Record 21 of Set 3 | iqaluit
# Processing Record 22 of Set 3 | saint george
# Processing Record 23 of Set 3 | hobart
# Processing Record 24 of Set 3 | gravdal
# Processing Record 25 of Set 3 | vostok
# Processing Record 26 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 27 of Set 3 | sao filipe
# Processing Record 28 of Set 3 | grao mogol
# Processing Record 29 of Set 3 | souillac
# Processing Record 30 of Set 3 | jacareacanga
# Processing Record 31 of Set 3 | chapais
# Processing Record 32 of Set 3 | pangnirtung
# Processing Record 33 of Set 3 | gulshat
# City not found. Skipping...
# Processing Record 34 of Set 3 | otacilio costa
# Processing Record 35 of Set 3 | tuatapere
# Processing Record 36 of Set 3 | margate
# Processing Record 37 of Set 3 | comodoro rivadavia
# Processing Record 38 of Set 3 | labuhan
# Processing Record 39 of Set 3 | port lincoln
# Processing Record 40 of Set 3 | sanchazi
# Processing Record 41 of Set 3 | bintulu
# Processing Record 42 of Set 3 | mahebourg
# Processing Record 43 of Set 3 | saint-pierre
# Processing Record 44 of Set 3 | geraldton
# Processing Record 45 of Set 3 | aswan
# Processing Record 46 of Set 3 | callaway
# Processing Record 47 of Set 3 | ambon
# Processing Record 48 of Set 3 | mount gambier
# Processing Record 49 of Set 3 | ancud
# Processing Record 50 of Set 3 | pandan
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | acari
# Processing Record 3 of Set 4 | batagay
# Processing Record 4 of Set 4 | butaritari
# Processing Record 5 of Set 4 | jackson
# Processing Record 6 of Set 4 | berlevag
# Processing Record 7 of Set 4 | port elizabeth
# Processing Record 8 of Set 4 | dudinka
# Processing Record 9 of Set 4 | clyde river
# Processing Record 10 of Set 4 | baykit
# Processing Record 11 of Set 4 | sept-iles
# Processing Record 12 of Set 4 | nanortalik
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | arman
# Processing Record 15 of Set 4 | beri
# Processing Record 16 of Set 4 | kloulklubed
# Processing Record 17 of Set 4 | puerto carreno
# Processing Record 18 of Set 4 | kenai
# Processing Record 19 of Set 4 | yellowknife
# Processing Record 20 of Set 4 | okhotsk
# Processing Record 21 of Set 4 | skiros
# City not found. Skipping...
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | tucuman
# Processing Record 24 of Set 4 | san patricio
# Processing Record 25 of Set 4 | bogotol
# Processing Record 26 of Set 4 | leeton
# Processing Record 27 of Set 4 | losal
# Processing Record 28 of Set 4 | jibuti
# Processing Record 29 of Set 4 | srednekolymsk
# Processing Record 30 of Set 4 | nijar
# Processing Record 31 of Set 4 | adamovka
# Processing Record 32 of Set 4 | dunedin
# Processing Record 33 of Set 4 | kytlym
# City not found. Skipping...
# Processing Record 34 of Set 4 | doha
# Processing Record 35 of Set 4 | westport
# Processing Record 36 of Set 4 | peterhead
# Processing Record 37 of Set 4 | sagua la grande
# Processing Record 38 of Set 4 | pevek
# Processing Record 39 of Set 4 | avera
# Processing Record 40 of Set 4 | ixtapa
# Processing Record 41 of Set 4 | hornepayne
# Processing Record 42 of Set 4 | saint-leu
# Processing Record 43 of Set 4 | myre
# Processing Record 44 of Set 4 | vila franca do campo
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | auce
# Processing Record 47 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 48 of Set 4 | harboore
# Processing Record 49 of Set 4 | mount isa
# Processing Record 50 of Set 4 | dauriya
# Processing Record 1 of Set 5 | jamestown
# Processing Record 2 of Set 5 | bull savanna
# Processing Record 3 of Set 5 | talnakh
# Processing Record 4 of Set 5 | kahone
# Processing Record 5 of Set 5 | port hedland
# Processing Record 6 of Set 5 | kitui
# Processing Record 7 of Set 5 | cabo san lucas
# Processing Record 8 of Set 5 | san isidro
# Processing Record 9 of Set 5 | sao joao da barra
# Processing Record 10 of Set 5 | kharhial
# Processing Record 11 of Set 5 | salinopolis
# Processing Record 12 of Set 5 | airai
# Processing Record 13 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 14 of Set 5 | ikwiriri
# Processing Record 15 of Set 5 | windsor
# Processing Record 16 of Set 5 | cherskiy
# Processing Record 17 of Set 5 | klaksvik
# Processing Record 18 of Set 5 | carutapera
# Processing Record 19 of Set 5 | porto novo
# Processing Record 20 of Set 5 | sibenik
# Processing Record 21 of Set 5 | balabac
# Processing Record 22 of Set 5 | palmer
# Processing Record 23 of Set 5 | honningsvag
# Processing Record 24 of Set 5 | kuryk
# Processing Record 25 of Set 5 | murray bridge
# Processing Record 26 of Set 5 | la ronge
# Processing Record 27 of Set 5 | sokolac
# Processing Record 28 of Set 5 | kurilsk
# Processing Record 29 of Set 5 | belaya gora
# Processing Record 30 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 31 of Set 5 | pasaco
# Processing Record 32 of Set 5 | juazeiro
# Processing Record 33 of Set 5 | victoria
# Processing Record 34 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 5 | chumikan
# Processing Record 36 of Set 5 | almeria
# Processing Record 37 of Set 5 | upernavik
# Processing Record 38 of Set 5 | touros
# Processing Record 39 of Set 5 | stilfontein
# Processing Record 40 of Set 5 | sobolevo
# Processing Record 41 of Set 5 | hami
# Processing Record 42 of Set 5 | aksu
# Processing Record 43 of Set 5 | tiznit
# Processing Record 44 of Set 5 | katherine
# Processing Record 45 of Set 5 | hobyo
# Processing Record 46 of Set 5 | yeppoon
# Processing Record 47 of Set 5 | asau
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | vila velha
# Processing Record 50 of Set 5 | sueca
# Processing Record 1 of Set 6 | dungarvan
# Processing Record 2 of Set 6 | tasiilaq
# Processing Record 3 of Set 6 | waterloo
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | alta gracia
# Processing Record 6 of Set 6 | achisay
# City not found. Skipping...
# Processing Record 7 of Set 6 | huarmey
# Processing Record 8 of Set 6 | bayji
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | luba
# Processing Record 11 of Set 6 | swan river
# Processing Record 12 of Set 6 | changtu
# Processing Record 13 of Set 6 | oktyabrskoye
# Processing Record 14 of Set 6 | dalby
# Processing Record 15 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 6 | taltal
# Processing Record 17 of Set 6 | the valley
# Processing Record 18 of Set 6 | acajutla
# Processing Record 19 of Set 6 | bone
# Processing Record 20 of Set 6 | kirkuk
# Processing Record 21 of Set 6 | meulaboh
# Processing Record 22 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 23 of Set 6 | pauini
# Processing Record 24 of Set 6 | monrovia
# Processing Record 25 of Set 6 | karmala
# Processing Record 26 of Set 6 | afgoye
# City not found. Skipping...
# Processing Record 27 of Set 6 | college
# Processing Record 28 of Set 6 | duncan
# Processing Record 29 of Set 6 | odesskoye
# Processing Record 30 of Set 6 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 6 | turbat
# Processing Record 32 of Set 6 | sitka
# Processing Record 33 of Set 6 | conde
# Processing Record 34 of Set 6 | isangel
# Processing Record 35 of Set 6 | san francisco
# Processing Record 36 of Set 6 | pokhara
# Processing Record 37 of Set 6 | severo-kurilsk
# Processing Record 38 of Set 6 | twentynine palms
# Processing Record 39 of Set 6 | benghazi
# Processing Record 40 of Set 6 | dakar
# Processing Record 41 of Set 6 | houma
# Processing Record 42 of Set 6 | ucluelet
# Processing Record 43 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 6 | dongsheng
# Processing Record 45 of Set 6 | chabahar
# Processing Record 46 of Set 6 | paamiut
# Processing Record 47 of Set 6 | beringovskiy
# Processing Record 48 of Set 6 | benjamin aceval
# Processing Record 49 of Set 6 | saldanha
# Processing Record 50 of Set 6 | crotone
# Processing Record 1 of Set 7 | grand gaube
# Processing Record 2 of Set 7 | sambava
# Processing Record 3 of Set 7 | aklavik
# Processing Record 4 of Set 7 | mutsu
# Processing Record 5 of Set 7 | lazaro cardenas
# Processing Record 6 of Set 7 | andenes
# Processing Record 7 of Set 7 | mokhsogollokh
# Processing Record 8 of Set 7 | port macquarie
# Processing Record 9 of Set 7 | vestmanna
# Processing Record 10 of Set 7 | oistins
# Processing Record 11 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 7 | chuy
# Processing Record 13 of Set 7 | beloha
# Processing Record 14 of Set 7 | zuwarah
# Processing Record 15 of Set 7 | pulgaon
# Processing Record 16 of Set 7 | morant bay
# Processing Record 17 of Set 7 | hasaki
# Processing Record 18 of Set 7 | samarai
# Processing Record 19 of Set 7 | yenagoa
# Processing Record 20 of Set 7 | tromso
# Processing Record 21 of Set 7 | odweyne
# Processing Record 22 of Set 7 | bontang
# Processing Record 23 of Set 7 | kaeo
# Processing Record 24 of Set 7 | namie
# Processing Record 25 of Set 7 | qui nhon
# Processing Record 26 of Set 7 | wanning
# Processing Record 27 of Set 7 | makushino
# Processing Record 28 of Set 7 | bubaque
# Processing Record 29 of Set 7 | harper
# Processing Record 30 of Set 7 | jalapa
# Processing Record 31 of Set 7 | gat
# Processing Record 32 of Set 7 | jijiga
# Processing Record 33 of Set 7 | marawi
# Processing Record 34 of Set 7 | yabrud
# Processing Record 35 of Set 7 | warmbad
# Processing Record 36 of Set 7 | marrakesh
# Processing Record 37 of Set 7 | nikolskoye
# Processing Record 38 of Set 7 | chokurdakh
# Processing Record 39 of Set 7 | sarakhs
# Processing Record 40 of Set 7 | atar
# Processing Record 41 of Set 7 | san andres
# Processing Record 42 of Set 7 | mana
# Processing Record 43 of Set 7 | cap malheureux
# Processing Record 44 of Set 7 | quatre cocos
# Processing Record 45 of Set 7 | nicoya
# Processing Record 46 of Set 7 | mayskiy
# Processing Record 47 of Set 7 | dwarka
# Processing Record 48 of Set 7 | bairiki
# Processing Record 49 of Set 7 | genhe
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | salas
# Processing Record 2 of Set 8 | hakodate
# Processing Record 3 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 8 | salalah
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | medicine hat
# Processing Record 7 of Set 8 | iwanai
# Processing Record 8 of Set 8 | bathsheba
# Processing Record 9 of Set 8 | alta floresta
# Processing Record 10 of Set 8 | creel
# Processing Record 11 of Set 8 | kaele
# Processing Record 12 of Set 8 | sabang
# Processing Record 13 of Set 8 | mayumba
# Processing Record 14 of Set 8 | chateaubelair
# Processing Record 15 of Set 8 | half moon bay
# Processing Record 16 of Set 8 | vao
# Processing Record 17 of Set 8 | afmadu
# City not found. Skipping...
# Processing Record 18 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 19 of Set 8 | hay river
# Processing Record 20 of Set 8 | te anau
# Processing Record 21 of Set 8 | gbarnga
# Processing Record 22 of Set 8 | nabire
# Processing Record 23 of Set 8 | arona
# Processing Record 24 of Set 8 | noyabrsk
# Processing Record 25 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 8 | deep river
# Processing Record 27 of Set 8 | fare
# Processing Record 28 of Set 8 | nhulunbuy
# Processing Record 29 of Set 8 | teguldet
# Processing Record 30 of Set 8 | tuktoyaktuk
# Processing Record 31 of Set 8 | altamira
# Processing Record 32 of Set 8 | amga
# Processing Record 33 of Set 8 | south lake tahoe
# Processing Record 34 of Set 8 | mae chan
# Processing Record 35 of Set 8 | vidim
# Processing Record 36 of Set 8 | kidal
# Processing Record 37 of Set 8 | kodiak
# Processing Record 38 of Set 8 | anchorage
# Processing Record 39 of Set 8 | haines junction
# Processing Record 40 of Set 8 | dekoa
# City not found. Skipping...
# Processing Record 41 of Set 8 | laiwu
# Processing Record 42 of Set 8 | kamenka
# Processing Record 43 of Set 8 | bongued
# Processing Record 44 of Set 8 | gwadar
# Processing Record 45 of Set 8 | ishigaki
# Processing Record 46 of Set 8 | noumea
# Processing Record 47 of Set 8 | wittmund
# Processing Record 48 of Set 8 | inirida
# Processing Record 49 of Set 8 | tabuk
# Processing Record 50 of Set 8 | kahului
# Processing Record 1 of Set 9 | sinnamary
# Processing Record 2 of Set 9 | alappuzha
# Processing Record 3 of Set 9 | lungi
# Processing Record 4 of Set 9 | pringsewu
# Processing Record 5 of Set 9 | gorele
# Processing Record 6 of Set 9 | kaitangata
# Processing Record 7 of Set 9 | marzuq
# Processing Record 8 of Set 9 | havoysund
# Processing Record 9 of Set 9 | tondano
# Processing Record 10 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 9 | betioky
# Processing Record 12 of Set 9 | hakkari
# Processing Record 13 of Set 9 | yumen
# Processing Record 14 of Set 9 | matameye
# City not found. Skipping...
# Processing Record 15 of Set 9 | fallon
# Processing Record 16 of Set 9 | chimbote
# Processing Record 17 of Set 9 | rivadavia
# Processing Record 18 of Set 9 | fukue
# Processing Record 19 of Set 9 | qandala
# Processing Record 20 of Set 9 | melfort
# Processing Record 21 of Set 9 | guipavas
# Processing Record 22 of Set 9 | smithers
# Processing Record 23 of Set 9 | adrar
# Processing Record 24 of Set 9 | cartagena
# Processing Record 25 of Set 9 | evanston
# Processing Record 26 of Set 9 | arroyo
# Processing Record 27 of Set 9 | san jeronimo
# Processing Record 28 of Set 9 | pokosnoye
# Processing Record 29 of Set 9 | doka
# Processing Record 30 of Set 9 | olafsvik
# Processing Record 31 of Set 9 | hervey bay
# Processing Record 32 of Set 9 | athabasca
# Processing Record 33 of Set 9 | bahia blanca
# Processing Record 34 of Set 9 | lata
# Processing Record 35 of Set 9 | tevriz
# Processing Record 36 of Set 9 | ashland
# Processing Record 37 of Set 9 | kabinda
# Processing Record 38 of Set 9 | dodge city
# Processing Record 39 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 9 | mamallapuram
# Processing Record 41 of Set 9 | faya
# Processing Record 42 of Set 9 | novyy urengoy
# Processing Record 43 of Set 9 | taunggyi
# Processing Record 44 of Set 9 | northam
# Processing Record 45 of Set 9 | baherden
# Processing Record 46 of Set 9 | nuevitas
# Processing Record 47 of Set 9 | rio gallegos
# Processing Record 48 of Set 9 | southbridge
# Processing Record 49 of Set 9 | abu zabad
# Processing Record 50 of Set 9 | ngunguru
# Processing Record 1 of Set 10 | juneau
# Processing Record 2 of Set 10 | coahuayana
# Processing Record 3 of Set 10 | chipinge
# Processing Record 4 of Set 10 | zhigansk
# Processing Record 5 of Set 10 | causapscal
# Processing Record 6 of Set 10 | bud
# Processing Record 7 of Set 10 | jumla
# Processing Record 8 of Set 10 | balimo
# City not found. Skipping...
# Processing Record 9 of Set 10 | lingao
# Processing Record 10 of Set 10 | necochea
# Processing Record 11 of Set 10 | waipawa
# Processing Record 12 of Set 10 | imbituba
# Processing Record 13 of Set 10 | chapleau
# Processing Record 14 of Set 10 | cururupu
# Processing Record 15 of Set 10 | kota bahru
# Processing Record 16 of Set 10 | hoima
# Processing Record 17 of Set 10 | broome
# Processing Record 18 of Set 10 | pierre
# Processing Record 19 of Set 10 | makakilo city
# Processing Record 20 of Set 10 | novokayakent
# Processing Record 21 of Set 10 | sao joaquim
# Processing Record 22 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 23 of Set 10 | moussoro
# Processing Record 24 of Set 10 | phalombe
# Processing Record 25 of Set 10 | port hardy
# Processing Record 26 of Set 10 | ust-tsilma
# Processing Record 27 of Set 10 | pizarro
# Processing Record 28 of Set 10 | itarema
# Processing Record 29 of Set 10 | morgan city
# Processing Record 30 of Set 10 | san cristobal
# Processing Record 31 of Set 10 | amalapuram
# Processing Record 32 of Set 10 | rocha
# Processing Record 33 of Set 10 | aleksandrovskoye
# Processing Record 34 of Set 10 | kukmor
# Processing Record 35 of Set 10 | ashtian
# Processing Record 36 of Set 10 | norwich
# Processing Record 37 of Set 10 | sampit
# Processing Record 38 of Set 10 | nampula
# Processing Record 39 of Set 10 | zhanakorgan
# Processing Record 40 of Set 10 | paita
# Processing Record 41 of Set 10 | gorontalo
# Processing Record 42 of Set 10 | bima
# Processing Record 43 of Set 10 | corumba
# Processing Record 44 of Set 10 | daru
# Processing Record 45 of Set 10 | cam ranh
# Processing Record 46 of Set 10 | lemesos
# City not found. Skipping...
# Processing Record 47 of Set 10 | yerbogachen
# Processing Record 48 of Set 10 | biak
# Processing Record 49 of Set 10 | cascais
# Processing Record 50 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 1 of Set 11 | riyadh
# Processing Record 2 of Set 11 | kozhva
# Processing Record 3 of Set 11 | bonavista
# Processing Record 4 of Set 11 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 11 | mpulungu
# Processing Record 6 of Set 11 | nguruka
# Processing Record 7 of Set 11 | mayya
# Processing Record 8 of Set 11 | carauari
# Processing Record 9 of Set 11 | navolato
# Processing Record 10 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 11 of Set 11 | atasu
# Processing Record 12 of Set 11 | erzin
# Processing Record 13 of Set 11 | bobo dioulasso
# Processing Record 14 of Set 11 | kommunar
# Processing Record 15 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 17 of Set 11 | mount pleasant
# Processing Record 18 of Set 11 | los llanos de aridane
# Processing Record 19 of Set 11 | novyy urgal
# Processing Record 20 of Set 11 | solnechnyy
# Processing Record 21 of Set 11 | south sioux city
# Processing Record 22 of Set 11 | wattegama
# Processing Record 23 of Set 11 | laguna
# Processing Record 24 of Set 11 | jiuquan
# Processing Record 25 of Set 11 | impfondo
# Processing Record 26 of Set 11 | poum
# Processing Record 27 of Set 11 | bertoua
# Processing Record 28 of Set 11 | zavyalovo
# Processing Record 29 of Set 11 | tomatlan
# Processing Record 30 of Set 11 | chingirlau
# Processing Record 31 of Set 11 | nikki
# Processing Record 32 of Set 11 | maraa
# Processing Record 33 of Set 11 | pareora
# Processing Record 34 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 35 of Set 11 | saint-georges
# Processing Record 36 of Set 11 | palu
# Processing Record 37 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 38 of Set 11 | pontian kecil
# Processing Record 39 of Set 11 | bilibino
# Processing Record 40 of Set 11 | tretten
# Processing Record 41 of Set 11 | arlit
# Processing Record 42 of Set 11 | tecoanapa
# Processing Record 43 of Set 11 | bundaberg
# Processing Record 44 of Set 11 | krasnoselkup
# Processing Record 45 of Set 11 | olden
# Processing Record 46 of Set 11 | ukiah
# Processing Record 47 of Set 11 | omboue
# Processing Record 48 of Set 11 | ndioum
# Processing Record 49 of Set 11 | rosignol
# Processing Record 50 of Set 11 | bagdarin
# Processing Record 1 of Set 12 | bujumbura
# Processing Record 2 of Set 12 | patnagarh
# Processing Record 3 of Set 12 | kysyl-syr
# Processing Record 4 of Set 12 | malmesbury
# Processing Record 5 of Set 12 | shalyhyne
# Processing Record 6 of Set 12 | broken hill
# Processing Record 7 of Set 12 | sayyan
# City not found. Skipping...
# Processing Record 8 of Set 12 | tayu
# Processing Record 9 of Set 12 | sable-sur-sarthe
# Processing Record 10 of Set 12 | guerrero negro
# Processing Record 11 of Set 12 | sabha
# Processing Record 12 of Set 12 | antigonish
# Processing Record 13 of Set 12 | thap than
# Processing Record 14 of Set 12 | acapulco
# Processing Record 15 of Set 12 | sirjan
# Processing Record 16 of Set 12 | nouadhibou
# Processing Record 17 of Set 12 | suntar
# Processing Record 18 of Set 12 | sao joao do piaui
# Processing Record 19 of Set 12 | orlik
# Processing Record 20 of Set 12 | yar-sale
# Processing Record 21 of Set 12 | vrangel
# Processing Record 22 of Set 12 | aripuana
# Processing Record 23 of Set 12 | mahina
# Processing Record 24 of Set 12 | pacific grove
# Processing Record 25 of Set 12 | larreynaga
# Processing Record 26 of Set 12 | yayva
# Processing Record 27 of Set 12 | mazyr
# Processing Record 28 of Set 12 | morondava
# Processing Record 29 of Set 12 | chipata
# Processing Record 30 of Set 12 | praia da vitoria
# Processing Record 31 of Set 12 | kontagora
# Processing Record 32 of Set 12 | inta
# Processing Record 33 of Set 12 | saqqez
# Processing Record 34 of Set 12 | bridlington
# Processing Record 35 of Set 12 | garm
# City not found. Skipping...
# Processing Record 36 of Set 12 | oranjemund
# Processing Record 37 of Set 12 | lere
# Processing Record 38 of Set 12 | athens
# Processing Record 39 of Set 12 | vestmannaeyjar
# Processing Record 40 of Set 12 | dire
# Processing Record 41 of Set 12 | coxim
# Processing Record 42 of Set 12 | antalaha
# Processing Record 43 of Set 12 | sovetskiy
# Processing Record 44 of Set 12 | balakhta
# Processing Record 45 of Set 12 | darnah
# Processing Record 46 of Set 12 | katsuura
# Processing Record 47 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 48 of Set 12 | santiago
# Processing Record 49 of Set 12 | puerto gaitan
# Processing Record 50 of Set 12 | maturin
# Processing Record 1 of Set 13 | bam
# Processing Record 2 of Set 13 | puerto escondido
# Processing Record 3 of Set 13 | atambua
# Processing Record 4 of Set 13 | iberia
# Processing Record 5 of Set 13 | port said
# Processing Record 6 of Set 13 | hachinohe
# Processing Record 7 of Set 13 | roma
# Processing Record 8 of Set 13 | byron bay
# Processing Record 9 of Set 13 | haian
# Processing Record 10 of Set 13 | pemangkat
# Processing Record 11 of Set 13 | kashi
# Processing Record 12 of Set 13 | axim
# Processing Record 13 of Set 13 | itoman
# Processing Record 14 of Set 13 | alofi
# Processing Record 15 of Set 13 | albina
# Processing Record 16 of Set 13 | porterville
# Processing Record 17 of Set 13 | sumter
# Processing Record 18 of Set 13 | kibala
# Processing Record 19 of Set 13 | kouvola
# Processing Record 20 of Set 13 | santa rosa
# Processing Record 21 of Set 13 | pecos
# Processing Record 22 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 23 of Set 13 | balakhninskiy
# Processing Record 24 of Set 13 | thinadhoo
# Processing Record 25 of Set 13 | chany
# Processing Record 26 of Set 13 | flinders
# Processing Record 27 of Set 13 | ust-omchug
# Processing Record 28 of Set 13 | bowling green
# Processing Record 29 of Set 13 | copparo
# Processing Record 30 of Set 13 | gobabis
# Processing Record 31 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 32 of Set 13 | tsabong
# Processing Record 33 of Set 13 | boone
# Processing Record 34 of Set 13 | cartagena del chaira
# Processing Record 35 of Set 13 | opochka
# Processing Record 36 of Set 13 | borogontsy
# Processing Record 37 of Set 13 | xai-xai
# Processing Record 38 of Set 13 | buchanan
# Processing Record 39 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 13 | roros
# Processing Record 41 of Set 13 | moron
# Processing Record 42 of Set 13 | kalmunai
# Processing Record 43 of Set 13 | novoagansk
# Processing Record 44 of Set 13 | tessalit
# Processing Record 45 of Set 13 | kiama
# Processing Record 46 of Set 13 | jinxiang
# Processing Record 47 of Set 13 | narsaq
# Processing Record 48 of Set 13 | hualmay
# Processing Record 49 of Set 13 | roquetas de mar
# Processing Record 50 of Set 13 | bardiyah
# Processing Record 1 of Set 14 | lethem
# Processing Record 2 of Set 14 | kieta
# Processing Record 3 of Set 14 | kropotkin
# Processing Record 4 of Set 14 | tidore
# City not found. Skipping...
# Processing Record 5 of Set 14 | kandrian
# Processing Record 6 of Set 14 | natal
# Processing Record 7 of Set 14 | soyo
# Processing Record 8 of Set 14 | guajara-mirim
# City not found. Skipping...
# Processing Record 9 of Set 14 | paraguacu paulista
# Processing Record 10 of Set 14 | harwich
# Processing Record 11 of Set 14 | mahajanga
# Processing Record 12 of Set 14 | bambanglipuro
# Processing Record 13 of Set 14 | semnan
# Processing Record 14 of Set 14 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 15 of Set 14 | severomorsk
# Processing Record 16 of Set 14 | amarante do maranhao
# Processing Record 17 of Set 14 | antofagasta
# Processing Record 18 of Set 14 | warren
# Processing Record 19 of Set 14 | mackay
# Processing Record 20 of Set 14 | murgab
# Processing Record 21 of Set 14 | rodino
# Processing Record 22 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 23 of Set 14 | sisimiut
# Processing Record 24 of Set 14 | orcopampa
# Processing Record 25 of Set 14 | chepareria
# Processing Record 26 of Set 14 | karamay
# City not found. Skipping...
# Processing Record 27 of Set 14 | cascavel
# Processing Record 28 of Set 14 | korla
# Processing Record 29 of Set 14 | sechura
# Processing Record 30 of Set 14 | tancitaro
# Processing Record 31 of Set 14 | shangrao
# Processing Record 32 of Set 14 | black river
# Processing Record 33 of Set 14 | redlands
# Processing Record 34 of Set 14 | zlobin
# Processing Record 35 of Set 14 | chicama
# Processing Record 36 of Set 14 | primorsk
# Processing Record 37 of Set 14 | borujan
# City not found. Skipping...
# Processing Record 38 of Set 14 | bourail
# Processing Record 39 of Set 14 | santa cruz de la palma
# Processing Record 40 of Set 14 | quesnel
# Processing Record 41 of Set 14 | shimoda
# Processing Record 42 of Set 14 | praia
# Processing Record 43 of Set 14 | katobu
# Processing Record 44 of Set 14 | nalut
# Processing Record 45 of Set 14 | buraydah
# Processing Record 46 of Set 14 | ola
# Processing Record 47 of Set 14 | ambilobe
# Processing Record 48 of Set 14 | maldonado
# Processing Record 49 of Set 14 | puerto ayacucho
# Processing Record 50 of Set 14 | tutoia
# Processing Record 1 of Set 15 | sheridan
# Processing Record 2 of Set 15 | abha
# Processing Record 3 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 15 | zhelyabovka
# Processing Record 5 of Set 15 | barcelos
# Processing Record 6 of Set 15 | yining
# Processing Record 7 of Set 15 | uricani
# Processing Record 8 of Set 15 | dinsor
# City not found. Skipping...
# Processing Record 9 of Set 15 | aksay
# Processing Record 10 of Set 15 | yuancheng
# Processing Record 11 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 15 | luwuk
# Processing Record 13 of Set 15 | hun
# Processing Record 14 of Set 15 | garowe
# Processing Record 15 of Set 15 | akureyri
# Processing Record 16 of Set 15 | ossora
# Processing Record 17 of Set 15 | batangafo
# Processing Record 18 of Set 15 | rio grande
# Processing Record 19 of Set 15 | allapalli
# Processing Record 20 of Set 15 | aljezur
# Processing Record 21 of Set 15 | khandbari
# Processing Record 22 of Set 15 | tezu
# Processing Record 23 of Set 15 | namatanai
# Processing Record 24 of Set 15 | kholodnyy
# Processing Record 25 of Set 15 | opuwo
# Processing Record 26 of Set 15 | blagoyevo
# Processing Record 27 of Set 15 | aranos
# Processing Record 28 of Set 15 | alterosa
# Processing Record 29 of Set 15 | kinablangan
# Processing Record 30 of Set 15 | upington
# Processing Record 31 of Set 15 | nuoro
# Processing Record 32 of Set 15 | aykhal
# Processing Record 33 of Set 15 | chalchihuites
# Processing Record 34 of Set 15 | pochutla
# Processing Record 35 of Set 15 | felipe carrillo puerto
# Processing Record 36 of Set 15 | nyimba
# Processing Record 37 of Set 15 | rio brilhante
# Processing Record 38 of Set 15 | pontianak
# Processing Record 39 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 40 of Set 15 | muravlenko
# Processing Record 41 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 42 of Set 15 | codrington
# Processing Record 43 of Set 15 | pascagoula
# Processing Record 44 of Set 15 | galle
# Processing Record 45 of Set 15 | male
# Processing Record 46 of Set 15 | kalmar
# Processing Record 47 of Set 15 | madimba
# Processing Record 48 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 49 of Set 15 | barra do garcas
# Processing Record 50 of Set 15 | san pedro
# Processing Record 1 of Set 16 | aktau
# Processing Record 2 of Set 16 | ostrovnoy
# Processing Record 3 of Set 16 | adra
# Processing Record 4 of Set 16 | tupik
# Processing Record 5 of Set 16 | alice springs
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Rikitea      PF -23.1203 -134.9692     75.51        77         100
# 1  Novo Aripuana      BR  -5.1206  -60.3797     74.25        95          98
# 2        Aksarka      RU  66.5606   67.7975     14.04        88          96
# 3   Pilar Do Sul      BR -23.8131  -47.7164     58.93        94          35
# 4          Bluff      NZ -46.6000  168.3333     58.84        76          93
#
#    Wind Speed Current Description
# 0        8.93          light rain
# 1        1.28     overcast clouds
# 2        4.50     overcast clouds
# 3        6.73    scattered clouds
# 4       12.01     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
